# %%
import pandas as pd

# %%
df_org = pd.read_csv("kiemtra.csv")

# %%
df.head()
# Out:
#             farm pond       Date  day_age  Độ mặn  Độ kiềm        PH  \
# 0            NaN  NaN        NaN      NaN     NaN      NaN       NaN
# 1            NaN  NaN        NaN      NaN     NaN      NaN       NaN
# 2  Farm_Mien_Nam  2A3  4/16/2024     -2.0     NaN      NaN  8.279009
# 3  Farm_Mien_Nam  2A3  4/16/2024     -2.0    33.0    124.0  8.345266
# 4            NaN  NaN        NaN      NaN     NaN      NaN       NaN
#
#     Nhiệt độ  TDS module  TAN         type3
# 0        NaN  NaN  Khu_2  NaN  Culture Pond
# 1        NaN  NaN  Khu_2  NaN  Culture Pond
# 2  32.589119  NaN  Khu_2  NaN  Culture Pond
# 3  29.920036  NaN  Khu_2  NaN  Culture Pond
# 4        NaN  NaN  Khu_2  0.2  Culture Pond

# %%
df["pond"].value_counts()
# Out:
# pond
# 2A1    321
# 2A3    224
# 2B8    174
# 2A2    147
# 2A5    112
# 2B7    106
# 2A4    100
# 2C4      5
# 2C8      1
# 1D1      1
# Name: count, dtype: int64

# %%
df = df_org[(df_org['pond']=="2A1") | (df_org['pond']=="2A3")].copy()

# %%
df
# Out:
#                farm pond       Date  day_age     Độ mặn  Độ kiềm        PH  \
# 2     Farm_Mien_Nam  2A3  4/16/2024     -2.0        NaN      NaN  8.279009
# 3     Farm_Mien_Nam  2A3  4/16/2024     -2.0  33.000000    124.0  8.345266
# 5     Farm_Mien_Nam  2A1  4/16/2024     -2.0        NaN      NaN  8.251972
# 9     Farm_Mien_Nam  2A1  4/16/2024     -2.0  33.000000    122.0  8.322342
# 10    Farm_Mien_Nam  2A1  4/19/2024      1.0        NaN      NaN  8.419366
# ...             ...  ...        ...      ...        ...      ...       ...
# 1519  Farm_Mien_Nam  2A1   7/8/2024     81.0  30.811790      NaN  7.348712
# 1552  Farm_Mien_Nam  2A3  6/13/2024     56.0  36.030064      NaN  7.635260
# 1569  Farm_Mien_Nam  2A1  6/29/2024     72.0  35.176022      NaN  7.581730
# 1571  Farm_Mien_Nam  2A1  6/29/2024     72.0  35.176022      NaN  7.581730
# 1590  Farm_Mien_Nam  2A1   6/4/2024     47.0  31.286285      NaN  7.994517
#
#        Nhiệt độ        TDS module  TAN         type3
# ...

# %%
df.to_csv("ninhthuan.csv", index=False)
